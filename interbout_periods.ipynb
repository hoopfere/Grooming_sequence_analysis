# %%
from data_processing import get_interbout
import seaborn as sns

# %%
interbout_times = get_interbout("final_all_winners.csv")

p = sns.histplot(interbout_times)

p.set_yscale("log")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 interbout_times = get_interbout("final_all_winners.csv")
#       3 p = sns.histplot(interbout_times)
#       5 p.set_yscale("log")
#
# File ~/Documents/carleton/fly_syntax_nlp/data_processing.py:69, in get_interbout(filepath)
#      66 def get_interbout(filepath):
#      67     breaks = []
# ---> 69     for data in csv_to_dfs(filepath):
#      70         data = data.sort_values(by="start_time")
#      72         start_times = data["start_time"].tolist()
#
# File ~/Documents/carleton/fly_syntax_nlp/data_processing.py:44, in csv_to_dfs(filepath)
#      43 def csv_to_dfs(filepath):
# ---> 44     data = pd.read_csv(filepath)
#      45     data = data.query("behavior != 'class_all_grooming'")
#      47     dfs = [data[data["file"] == f].sort_values("start_time") for f in pd.unique(data["file"])]
#
# ...

# %%
interbout_times
# Out:
# [0.03300000000000114,
#  0.366,
#  0.03299999999999759,
#  0.2999999999999976,
#  0.03299999999999781,
#  0.9000000000000041,
#  1.1670000000000003,
#  0.43399999999999594,
#  0.034000000000001585,
#  8.167000000000002,
#  0.13400000000000012,
#  0.033000000000000806,
#  3.033000000000003,
#  0.032999999999994145,
#  4.133000000000003,
#  0.0339999999999922,
#  0.1670000000000018,
#  0.033000000000001195,
#  3.2000000000000033,
#  0.03399999999999148,
#  0.03300000000000125,
#  78.333,
#  0.03300000000001568,
#  0.033999999999991815,
#  0.03399999999999198,
#  3.200000000000017,
#  3.4330000000000216,
#  50.5,
#  1.6659999999999924,
#  0.06700000000000716,
#  3.967,
#  72.267,
#  0.03399999999998715,
#  0.03400000000000569,
#  1.2669999999999955,
#  6.200000000000005,
#  20.5,
#  0.032999999999997254,
#  39.76700000000001,
#  0.03300000000001546,
#  0.03299999999998304,
#  0.0329999999999869,
#  0.03299999999998743,
#  0.03300000000001568,
#  1.0339999999999958,
# ...
